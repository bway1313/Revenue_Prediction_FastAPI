# %% [markdown]
# **Upload Retail Data from Github
# Features include: BillNo, Itemname, Quantity, Date, Price, Customer, and Country**

# %%
#Import packages
import pandas as pd
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SequentialFeatureSelector
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#IF USING COLLAB uncomment
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#Load in Data
file_path = 'Data/Assignment-1_Data.xlsx'
df = pd.read_excel(file_path)
df.head()
# Out:
#    BillNo                             Itemname  Quantity                Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1  536365                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    Price  CustomerID         Country
# 0   2.55     17850.0  United Kingdom
# 1   3.39     17850.0  United Kingdom
# 2   2.75     17850.0  United Kingdom
# 3   3.39     17850.0  United Kingdom
# 4   3.39     17850.0  United Kingdom

# %% [markdown]
# **Data Exploration**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522064 entries, 0 to 522063
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   BillNo      522064 non-null  object
#  1   Itemname    520609 non-null  object
#  2   Quantity    522064 non-null  int64
#  3   Date        522064 non-null  datetime64[ns]
#  4   Price       522064 non-null  float64
#  5   CustomerID  388023 non-null  float64
#  6   Country     522064 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 27.9+ MB

# %%
df.describe()
# Out:
#             Quantity                           Date          Price  \
# count  522064.000000                         522064  522064.000000
# mean       10.090435  2011-07-04 12:51:20.777107456       3.826801
# min     -9600.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-28 10:15:00       1.250000
# 50%         3.000000            2011-07-20 08:59:00       2.080000
# 75%        10.000000            2011-10-19 14:12:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   13541.330000
# std       161.110525                            NaN      41.900599
#
#           CustomerID
# count  388023.000000
# mean    15316.931710
# min     12346.000000
# 25%     13950.000000
# 50%     15265.000000
# 75%     16837.000000
# max     18287.000000
# std      1721.846964

# %% [markdown]
# **Variable adjustments, convert Itemname and Country into categorical variables, and convert the date variable to a usable form**

# %%
#Convert Item Name into Categorical Variable
df['Itemname'].value_counts()
print(df['Itemname'].head())
# Out:
# 0     WHITE HANGING HEART T-LIGHT HOLDER
# 1                    WHITE METAL LANTERN
# 2         CREAM CUPID HEARTS COAT HANGER
# 3    KNITTED UNION FLAG HOT WATER BOTTLE
# 4         RED WOOLLY HOTTIE WHITE HEART.
# Name: Itemname, dtype: object

# %%
#Convert Country into Categorical Variable
df['Country'].value_counts()
print(df['Country'].head())
# Out:
# 0    United Kingdom
# 1    United Kingdom
# 2    United Kingdom
# 3    United Kingdom
# 4    United Kingdom
# Name: Country, dtype: object

# %%
#Convert Date Variable to be only the day
df['Date'] = pd.to_datetime(df['Date'])
df['DateOnly'] = df['Date'].dt.date
print(df['DateOnly'].head())
# Out:
# 0    2010-12-01
# 1    2010-12-01
# 2    2010-12-01
# 3    2010-12-01
# 4    2010-12-01
# Name: DateOnly, dtype: object

# %%
#Make Is Weekday variable
df['is_weekday'] = df['Date'].dt.weekday < 5
df['is_weekday'] = df['is_weekday'].astype(int) #convert boolean so instead of true/false you get 1/0
print(df['is_weekday'].head())
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: is_weekday, dtype: int32

# %%
#Make Dependent Variable - Revenue per day
df['Revenue'] = df['Price'] * df['Quantity']                           #revenue per transaction
daily_revenue = df.groupby('DateOnly')['Revenue'].sum().reset_index()  #Group by day
daily_revenue.columns = ['DateOnly', 'Daily_Revenue']
print(daily_revenue.head())
# Out:
#      DateOnly  Daily_Revenue
# 0  2010-12-01       58405.41
# 1  2010-12-02       47725.88
# 2  2010-12-03       44366.86
# 3  2010-12-05       31774.95
# 4  2010-12-06       53647.96

# %%
#Make Daily Quantity Variable
daily_quantity = df.groupby('DateOnly')['Quantity'].sum().reset_index()
daily_quantity.columns = ['DateOnly', 'Daily_Quantity']
print(df.columns)
# Out:
# Index(['BillNo', 'Itemname', 'Quantity', 'Date', 'Price', 'CustomerID',
#        'Country', 'DateOnly', 'is_weekday', 'Revenue'],
#       dtype='object')

# %%
print(daily_quantity.head())
# Out:
#      DateOnly  Daily_Quantity
# 0  2010-12-01           26754
# 1  2010-12-02           31304
# 2  2010-12-03           12546
# 3  2010-12-05           16451
# 4  2010-12-06           21104

# %%
print(df.head())
# Out:
#    BillNo                             Itemname  Quantity                Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1  536365                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    Price  CustomerID         Country    DateOnly  is_weekday  Revenue
# 0   2.55     17850.0  United Kingdom  2010-12-01           1    15.30
# 1   3.39     17850.0  United Kingdom  2010-12-01           1    20.34
# 2   2.75     17850.0  United Kingdom  2010-12-01           1    22.00
# 3   3.39     17850.0  United Kingdom  2010-12-01           1    20.34
# 4   3.39     17850.0  United Kingdom  2010-12-01           1    20.34

# %%
#Merge two new variables with original dataset
df = df.merge(daily_revenue, on='DateOnly', how='left')
df = df.merge(daily_quantity, on='DateOnly', how='left')
print(df.head())
# Out:
#    BillNo                             Itemname  Quantity                Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1  536365                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    Price  CustomerID         Country    DateOnly  is_weekday  Revenue  \
# 0   2.55     17850.0  United Kingdom  2010-12-01           1    15.30
# 1   3.39     17850.0  United Kingdom  2010-12-01           1    20.34
# 2   2.75     17850.0  United Kingdom  2010-12-01           1    22.00
# 3   3.39     17850.0  United Kingdom  2010-12-01           1    20.34
# 4   3.39     17850.0  United Kingdom  2010-12-01           1    20.34
#
#    Daily_Revenue  Daily_Quantity
# 0       58405.41           26754
# 1       58405.41           26754
# 2       58405.41           26754
# 3       58405.41           26754
# 4       58405.41           26754

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522064 entries, 0 to 522063
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   BillNo          522064 non-null  object
#  1   Itemname        520609 non-null  object
#  2   Quantity        522064 non-null  int64
#  3   Date            522064 non-null  datetime64[ns]
#  4   Price           522064 non-null  float64
#  5   CustomerID      388023 non-null  float64
#  6   Country         522064 non-null  object
#  7   DateOnly        522064 non-null  object
#  8   is_weekday      522064 non-null  int32
#  9   Revenue         522064 non-null  float64
#  10  Daily_Revenue   522064 non-null  float64
#  11  Daily_Quantity  522064 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int32(1), int64(2), object(4)
# memory usage: 45.8+ MB

# %% [markdown]
# ### Load Additional Gas & CPI Feature Data

# %%
#Weekly Gas Prices
gas_df = pd.read_csv('Data/Gas_Prices.csv')
gas_df.head()
# Out:
#            Date  \
# 0  Apr 05, 1993
# 1  Apr 12, 1993
# 2  Apr 19, 1993
# 3  Apr 26, 1993
# 4  May 03, 1993
#
#    Weekly U.S. All Grades All Formulations Retail Gasoline Prices  (Dollars per Gallon)
# 0                                              1.068
# 1                                              1.079
# 2                                              1.079
# 3                                              1.086
# 4                                              1.086

# %%
#Monthly Consumer Price Index (CPI)
cpi_df = pd.read_csv('Data/CPI_data.csv')
cpi_df.head()
# Out:
#        Date  CPI
# 0  1/1/2010  2.6
# 1  2/1/2010  2.1
# 2  3/1/2010  2.3
# 3  4/1/2010  2.2
# 4  5/1/2010  2.0

# %%
cpi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    36 non-null     object
#  1   CPI     36 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 708.0+ bytes

# %%
# Ensure date columns are in datetime format
df['Date'] = pd.to_datetime(df['Date'])
gas_df['Date'] = pd.to_datetime(gas_df['Date'])

# Check the columns of gas_df to identify the correct column name for gas prices
print(gas_df.columns)

# Rename the gas price column based on the exact column name in gas_df
gas_df.rename(columns={'Weekly U.S. All Grades All Formulations Retail Gasoline Prices  (Dollars per Gallon)': 'Gas_Price'}, inplace=True)
# Out:
# Index(['Date', 'Weekly U.S. All Grades All Formulations Retail Gasoline Prices  (Dollars per Gallon)'], dtype='object')

# %%
gas_df
# Out:
#            Date  Gas_Price
# 0    1993-04-05      1.068
# 1    1993-04-12      1.079
# 2    1993-04-19      1.079
# 3    1993-04-26      1.086
# 4    1993-05-03      1.086
# ...         ...        ...
# 1645 2024-10-14      3.294
# 1646 2024-10-21      3.268
# 1647 2024-10-28      3.220
# 1648 2024-11-04      3.191
# 1649        NaT        NaN
#
# [1650 rows x 2 columns]

# %%
# Ensure only date parts are in 'Date' columns for both dataframes
df['Date'] = pd.to_datetime(df['Date']).dt.date
gas_df['Date'] = pd.to_datetime(gas_df['Date']).dt.date

# Convert 'Date' back to datetime format for both dataframes for consistent merging
df['Date'] = pd.to_datetime(df['Date'])
gas_df['Date'] = pd.to_datetime(gas_df['Date'])

# Perform the merge on 'Date' and fill missing values for gas prices
df = df.merge(gas_df[['Date', 'Gas_Price']], how='left', on='Date')

# Use forward fill and backward fill to handle any remaining NaN values in Gas_Price
df['Gas_Price'] = df['Gas_Price'].ffill().bfill()

# Display the result to verify
print(df.head())
# Out:
#    BillNo                             Itemname  Quantity       Date  Price  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01   2.55
# 1  536365                  WHITE METAL LANTERN         6 2010-12-01   3.39
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01   2.75
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01   3.39
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01   3.39
#
#    CustomerID         Country    DateOnly  is_weekday  Revenue  Daily_Revenue  \
# 0     17850.0  United Kingdom  2010-12-01           1    15.30       58405.41
# 1     17850.0  United Kingdom  2010-12-01           1    20.34       58405.41
# 2     17850.0  United Kingdom  2010-12-01           1    22.00       58405.41
# 3     17850.0  United Kingdom  2010-12-01           1    20.34       58405.41
# 4     17850.0  United Kingdom  2010-12-01           1    20.34       58405.41
#
#    Daily_Quantity  Gas_Price
# 0           26754      3.013
# 1           26754      3.013
# 2           26754      3.013
# 3           26754      3.013
# 4           26754      3.013

# %%
# Ensure the 'Date' columns in df and cpi_df are in datetime format
df['Date'] = pd.to_datetime(df['Date']).dt.date
cpi_df['Date'] = pd.to_datetime(cpi_df['Date']).dt.date

# Convert back to datetime format for merging
df['Date'] = pd.to_datetime(df['Date'])
cpi_df['Date'] = pd.to_datetime(cpi_df['Date'])

# Sort cpi_df by Date to prepare for an asof merge or forward fill
cpi_df = cpi_df.sort_values('Date')

# Perform an asof merge to get the closest previous CPI for each date in df
df = pd.merge_asof(df.sort_values('Date'), cpi_df[['Date', 'CPI']], on='Date', direction='backward')

# Display the result to verify
print(df.head())
# Out:
#    BillNo                            Itemname  Quantity       Date  Price  \
# 0  536365  WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01   2.55
# 1  536557               BEACH HUT KEY CABINET         1 2010-12-01   3.75
# 2  536557             HOME SMALL WOOD LETTERS         1 2010-12-01   4.95
# 3  536557     SET OF 3 BABUSHKA STACKING TINS         1 2010-12-01   4.95
# 4  536557      SMALL PURPLE BABUSHKA NOTEBOOK        11 2010-12-01   0.85
#
#    CustomerID         Country    DateOnly  is_weekday  Revenue  Daily_Revenue  \
# 0     17850.0  United Kingdom  2010-12-01           1    15.30       58405.41
# 1     17841.0  United Kingdom  2010-12-01           1     3.75       58405.41
# 2     17841.0  United Kingdom  2010-12-01           1     4.95       58405.41
# 3     17841.0  United Kingdom  2010-12-01           1     4.95       58405.41
# 4     17841.0  United Kingdom  2010-12-01           1     9.35       58405.41
#
#    Daily_Quantity  Gas_Price  CPI
# 0           26754      3.013  1.5
# 1           26754      3.013  1.5
# 2           26754      3.013  1.5
# 3           26754      3.013  1.5
# 4           26754      3.013  1.5

# %%
#rename df with addtional features
df_ft = df

# %%
df_ft
# Out:
#         BillNo                            Itemname  Quantity       Date  \
# 0       536365  WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01
# 1       536557               BEACH HUT KEY CABINET         1 2010-12-01
# 2       536557             HOME SMALL WOOD LETTERS         1 2010-12-01
# 3       536557     SET OF 3 BABUSHKA STACKING TINS         1 2010-12-01
# 4       536557      SMALL PURPLE BABUSHKA NOTEBOOK        11 2010-12-01
# ...        ...                                 ...       ...        ...
# 522059  581492   GLASS JAR DAISY FRESH COTTON WOOL         2 2011-12-09
# 522060  581492              KINGS CHOICE TEA CADDY         1 2011-12-09
# 522061  581492            KINGS CHOICE BISCUIT TIN         2 2011-12-09
# 522062  581492  SET/4 RED MINI ROSE CANDLE IN BOWL         5 2011-12-09
# 522063  581587        BAKING SET 9 PIECE RETROSPOT         3 2011-12-09
#
#         Price  CustomerID         Country    DateOnly  is_weekday  Revenue  \
# 0        2.55     17850.0  United Kingdom  2010-12-01           1    15.30
# 1        3.75     17841.0  United Kingdom  2010-12-01           1     3.75
# 2        4.95     17841.0  United Kingdom  2010-12-01           1     4.95
# 3        4.95     17841.0  United Kingdom  2010-12-01           1     4.95
# 4        0.85     17841.0  United Kingdom  2010-12-01           1     9.35
# ...       ...         ...             ...         ...         ...      ...
# 522059   5.79         NaN  United Kingdom  2011-12-09           1    11.58
# 522060   5.79         NaN  United Kingdom  2011-12-09           1     5.79
# 522061   4.13         NaN  United Kingdom  2011-12-09           1     8.26
# 522062   1.63         NaN  United Kingdom  2011-12-09           1     8.15
# 522063   4.95     12680.0          France  2011-12-09           1    14.85
#
#         Daily_Revenue  Daily_Quantity  Gas_Price  CPI
# 0            58405.41           26754      3.013  1.5
# 1            58405.41           26754      3.013  1.5
# 2            58405.41           26754      3.013  1.5
# 3            58405.41           26754      3.013  1.5
# 4            58405.41           26754      3.013  1.5
# ...               ...             ...        ...  ...
# 522059      200920.60           93979      3.350  3.0
# 522060      200920.60           93979      3.350  3.0
# 522061      200920.60           93979      3.350  3.0
# 522062      200920.60           93979      3.350  3.0
# 522063      200920.60           93979      3.350  3.0
#
# [522064 rows x 14 columns]

# %% [markdown]
# ###  The data on 09 December 2011 is a clear outlier, probably captures data beyond the actual date since it is the last date. We will remove this data for the purposes of our model

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'DateOnly' is the date column and 'Daily_Revenue' is the revenue column
plt.figure(figsize=(14, 7))
sns.lineplot(data=df_ft, x="DateOnly", y="Daily_Revenue")
plt.title("Daily Revenue Over Time")
plt.xlabel("Date")
plt.ylabel("Daily Revenue")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# C:\Users\mothe\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\mothe\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Dropping rows with date of 12 December 2009
df_ft = df_ft[df_ft['DateOnly'] != '2011-12-09']

# Confirm the result by displaying the first few rows
df_ft
# Out:
#         BillNo                            Itemname  Quantity       Date  \
# 0       536365  WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01
# 1       536557               BEACH HUT KEY CABINET         1 2010-12-01
# 2       536557             HOME SMALL WOOD LETTERS         1 2010-12-01
# 3       536557     SET OF 3 BABUSHKA STACKING TINS         1 2010-12-01
# 4       536557      SMALL PURPLE BABUSHKA NOTEBOOK        11 2010-12-01
# ...        ...                                 ...       ...        ...
# 522059  581492   GLASS JAR DAISY FRESH COTTON WOOL         2 2011-12-09
# 522060  581492              KINGS CHOICE TEA CADDY         1 2011-12-09
# 522061  581492            KINGS CHOICE BISCUIT TIN         2 2011-12-09
# 522062  581492  SET/4 RED MINI ROSE CANDLE IN BOWL         5 2011-12-09
# 522063  581587        BAKING SET 9 PIECE RETROSPOT         3 2011-12-09
#
#         Price  CustomerID         Country    DateOnly  is_weekday  Revenue  \
# 0        2.55     17850.0  United Kingdom  2010-12-01           1    15.30
# 1        3.75     17841.0  United Kingdom  2010-12-01           1     3.75
# 2        4.95     17841.0  United Kingdom  2010-12-01           1     4.95
# 3        4.95     17841.0  United Kingdom  2010-12-01           1     4.95
# 4        0.85     17841.0  United Kingdom  2010-12-01           1     9.35
# ...       ...         ...             ...         ...         ...      ...
# 522059   5.79         NaN  United Kingdom  2011-12-09           1    11.58
# 522060   5.79         NaN  United Kingdom  2011-12-09           1     5.79
# 522061   4.13         NaN  United Kingdom  2011-12-09           1     8.26
# 522062   1.63         NaN  United Kingdom  2011-12-09           1     8.15
# 522063   4.95     12680.0          France  2011-12-09           1    14.85
#
#         Daily_Revenue  Daily_Quantity  Gas_Price  CPI
# 0            58405.41           26754      3.013  1.5
# 1            58405.41           26754      3.013  1.5
# 2            58405.41           26754      3.013  1.5
# 3            58405.41           26754      3.013  1.5
# 4            58405.41           26754      3.013  1.5
# ...               ...             ...        ...  ...
# 522059      200920.60           93979      3.350  3.0
# 522060      200920.60           93979      3.350  3.0
# 522061      200920.60           93979      3.350  3.0
# 522062      200920.60           93979      3.350  3.0
# 522063      200920.60           93979      3.350  3.0
#
# [522064 rows x 14 columns]

# %%
# Create a 14-day lagged daily revenue feature
df_ft['Daily_Revenue_Lag14'] = df_ft['Daily_Revenue'].shift(14)

# Display the first few rows to confirm
df_ft.head()
# Out:
#    BillNo                            Itemname  Quantity       Date  Price  \
# 0  536365  WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01   2.55
# 1  536557               BEACH HUT KEY CABINET         1 2010-12-01   3.75
# 2  536557             HOME SMALL WOOD LETTERS         1 2010-12-01   4.95
# 3  536557     SET OF 3 BABUSHKA STACKING TINS         1 2010-12-01   4.95
# 4  536557      SMALL PURPLE BABUSHKA NOTEBOOK        11 2010-12-01   0.85
#
#    CustomerID         Country    DateOnly  is_weekday  Revenue  Daily_Revenue  \
# 0     17850.0  United Kingdom  2010-12-01           1    15.30       58405.41
# 1     17841.0  United Kingdom  2010-12-01           1     3.75       58405.41
# 2     17841.0  United Kingdom  2010-12-01           1     4.95       58405.41
# 3     17841.0  United Kingdom  2010-12-01           1     4.95       58405.41
# 4     17841.0  United Kingdom  2010-12-01           1     9.35       58405.41
#
#    Daily_Quantity  Gas_Price  CPI  Daily_Revenue_Lag14
# 0           26754      3.013  1.5                  NaN
# 1           26754      3.013  1.5                  NaN
# 2           26754      3.013  1.5                  NaN
# 3           26754      3.013  1.5                  NaN
# 4           26754      3.013  1.5                  NaN

# %%
df_ft['DateOnly'] = pd.to_datetime(df_ft['DateOnly'])

# Drop rows where DateOnly is between '2010-12-01' and '2010-12-14'
df_ft = df_ft[~((df_ft['DateOnly'] >= '2010-12-01') & (df_ft['DateOnly'] <= '2010-12-14'))]

# Display the first few rows to confirm
df_ft.head()
# Out:
#        BillNo                         Itemname  Quantity       Date  Price  \
# 30249  539038  RECIPE BOX PANTRY YELLOW DESIGN         6 2010-12-15   2.95
# 30250  539038        DANISH ROSE FOLDING CHAIR         4 2010-12-15   7.95
# 30251  539038            HEART OF WICKER LARGE        12 2010-12-15   2.95
# 30252  539038           JAM MAKING SET PRINTED        12 2010-12-15   1.45
# 30253  539038   ASSTD DESIGN 3D PAPER STICKERS        60 2010-12-15   0.21
#
#        CustomerID         Country   DateOnly  is_weekday  Revenue  \
# 30249     15641.0  United Kingdom 2010-12-15           1     17.7
# 30250     15641.0  United Kingdom 2010-12-15           1     31.8
# 30251     15641.0  United Kingdom 2010-12-15           1     35.4
# 30252     15641.0  United Kingdom 2010-12-15           1     17.4
# 30253     15641.0  United Kingdom 2010-12-15           1     12.6
#
#        Daily_Revenue  Daily_Quantity  Gas_Price  CPI  Daily_Revenue_Lag14
# 30249       30444.62           18488      3.035  1.5             43663.91
# 30250       30444.62           18488      3.035  1.5             43663.91
# 30251       30444.62           18488      3.035  1.5             43663.91
# 30252       30444.62           18488      3.035  1.5             43663.91
# 30253       30444.62           18488      3.035  1.5             43663.91

# %%
# Scatter plots of Daily Revenue and Daily Quantity with various features
fig, axes = plt.subplots(3, 2, figsize=(18, 14))
fig.suptitle('Comparisons of Daily Revenue and Daily Quantity with Various Features')

# Plot 1: Daily Revenue vs is_weekday
axes[0, 0].scatter(df_ft['is_weekday'], df_ft['Daily_Revenue'], alpha=0.5)
axes[0, 0].set_title('Daily Revenue vs is_weekday')
axes[0, 0].set_xlabel('is_weekday (1 for weekday)')
axes[0, 0].set_ylabel('Daily Revenue')

# Plot 2: Daily Quantity vs is_weekday
axes[0, 1].scatter(df_ft['is_weekday'], df_ft['Daily_Quantity'], alpha=0.5)
axes[0, 1].set_title('Daily Quantity vs is_weekday')
axes[0, 1].set_xlabel('is_weekday (1 for weekday)')
axes[0, 1].set_ylabel('Daily Quantity')

# Plot 3: Daily Revenue vs DateOnly
axes[1, 0].scatter(df_ft['DateOnly'], df_ft['Daily_Revenue'], alpha=0.5)
axes[1, 0].set_title('Daily Revenue vs DateOnly')
axes[1, 0].set_xlabel('Date')
axes[1, 0].set_ylabel('Daily Revenue')

# Plot 4: Daily Quantity vs DateOnly
axes[1, 1].scatter(df_ft['DateOnly'], df_ft['Daily_Quantity'], alpha=0.5)
axes[1, 1].set_title('Daily Quantity vs DateOnly')
axes[1, 1].set_xlabel('Date')
axes[1, 1].set_ylabel('Daily Quantity')

# Plot 5: Daily Revenue vs Country (using a numerical encoding for simplicity)
axes[2, 0].scatter(df_ft['Country'].astype('category').cat.codes, df_ft['Daily_Revenue'], alpha=0.5)
axes[2, 0].set_title('Daily Revenue vs Country')
axes[2, 0].set_xlabel('Country (encoded)')
axes[2, 0].set_ylabel('Daily Revenue')

# Plot 6: Daily Quantity vs Country (using a numerical encoding for simplicity)
axes[2, 1].scatter(df_ft['Country'].astype('category').cat.codes, df_ft['Daily_Quantity'], alpha=0.5)
axes[2, 1].set_title('Daily Quantity vs Country')
axes[2, 1].set_xlabel('Country (encoded)')
axes[2, 1].set_ylabel('Daily Quantity')

# Adjust layout for better spacing
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
# Additional plots for Gas_Price, CPI, and Daily_Revenue_Lag14 with DateOnly on the x-axis
fig, ax = plt.subplots(3, 1, figsize=(12, 14))

# Plot for Gas_Price
ax[0].plot(df_ft['DateOnly'], df_ft['Gas_Price'], marker='o', linestyle='-', alpha=0.7)
ax[0].set_title('Gas Price Over Time')
ax[0].set_xlabel('Date')
ax[0].set_ylabel('Gas Price')

# Plot for CPI
ax[1].plot(df_ft['DateOnly'], df_ft['CPI'], marker='o', linestyle='-', alpha=0.7)
ax[1].set_title('CPI Over Time')
ax[1].set_xlabel('Date')
ax[1].set_ylabel('CPI')

# Plot for Daily_Revenue_Lag14
ax[2].plot(df_ft['DateOnly'], df_ft['Daily_Revenue_Lag14'], marker='o', linestyle='-', alpha=0.7)
ax[2].set_title('Daily Revenue Lagged by 14 Days Over Time')
ax[2].set_xlabel('Date')
ax[2].set_ylabel('Daily Revenue Lag14')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
# Define the cutoff date
cutoff_date = '2011-11-01'

# Split the data
train_df = df_ft[df_ft['Date'] < cutoff_date]
test_df = df_ft[df_ft['Date'] >= cutoff_date]

# Separate features and target in each set if needed
x_train = train_df.drop(columns=['Daily_Revenue','BillNo','Itemname','Quantity','Date','Price','CustomerID','DateOnly','Revenue','Daily_Quantity','Country'])
y_train = train_df['Daily_Revenue']

x_test = test_df.drop(columns=['Daily_Revenue','BillNo','Itemname','Quantity','Date','Price','CustomerID','DateOnly','Revenue','Daily_Quantity','Country'])
y_test = test_df['Daily_Revenue']

# Verify the shapes
print("Training set:", x_train.shape, y_train.shape)
print("Validation set:", x_test.shape, y_test.shape)
# Out:
# Training set: (384777, 4) (384777,)
# Validation set: (107038, 4) (107038,)

# %%
# Ensure y_train and y_test are single columns (no duplicates)
x_train = x_train.squeeze()
y_train = y_train.squeeze()
x_test = x_test.squeeze()
y_test = y_test.squeeze()
# Verify the shapes
print("Training set:", x_train.shape, y_train.shape)
print("Validation set:", x_test.shape, y_test.shape)
# Out:
# Training set: (384777, 4) (384777,)
# Validation set: (107038, 4) (107038,)

# %% [markdown]
# **Build a linear regression model**

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Ensure x_train is a DataFrame (required for VIF calculation)
x_train_df = pd.DataFrame(x_train, columns=x_train.columns)

# Calculate VIF for each feature
vif_data = pd.DataFrame()
vif_data["Feature"] = x_train_df.columns
vif_data["VIF"] = [variance_inflation_factor(x_train_df.values, i) for i in range(x_train_df.shape[1])]

# Display the VIF values
print(vif_data)
# Out:
#                Feature        VIF
# 0           is_weekday  10.173359
# 1            Gas_Price  44.560212
# 2                  CPI  33.581050
# 3  Daily_Revenue_Lag14   6.796432

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler

# Initialize the scaler
scaler = StandardScaler()

# Fit the scaler on the training data and transform both training and test sets
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# Initialize the model
model = LinearRegression()

# Train the model on the scaled training data
model.fit(X_train_scaled, y_train)

# Make predictions on the scaled training set and evaluate
y_train_pred = model.predict(X_train_scaled)
train_mse = mean_squared_error(y_train, y_train_pred)
train_mae = mean_absolute_error(y_train, y_train_pred)
train_r2 = r2_score(y_train, y_train_pred)

print("Training Set Evaluation:")
print("Mean Squared Error:", train_mse)
print("Mean Absolute Error:", train_mae)
print("R^2 Score:", train_r2)

# Make predictions on the scaled test set and evaluate
y_test_pred = model.predict(X_test_scaled)
test_mse = mean_squared_error(y_test, y_test_pred)
test_mae = mean_absolute_error(y_test, y_test_pred)
test_r2 = r2_score(y_test, y_test_pred)

print("\nTest Set Evaluation:")
print("Mean Squared Error:", test_mse)
print("Mean Absolute Error:", test_mae)
print("R^2 Score:", test_r2)
# Out:
# Training Set Evaluation:
# Mean Squared Error: 3648809.4195123264
# Mean Absolute Error: 268.7939585878336
# R^2 Score: 0.9848596601031839
#
# Test Set Evaluation:
# Mean Squared Error: 5486524.123502061
# Mean Absolute Error: 411.96611840262284
# R^2 Score: 0.9915018583397542

# %% [markdown]
# Another linear regression model, this time removing 14 lag of revenue

# %%
import statsmodels.api as sm

# Convert X_train_scaled back to a DataFrame with column names for labeling
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=x_train.columns, index=y_train.index)

# Add a constant to the model (for the intercept)
X_train_const = sm.add_constant(X_train_scaled_df)

# Fit the model using statsmodels
model = sm.OLS(y_train, X_train_const).fit()

# Print the model summary with labeled features
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Daily_Revenue   R-squared:                       0.985
# Model:                            OLS   Adj. R-squared:                  0.985
# Method:                 Least Squares   F-statistic:                 6.257e+06
# Date:                Sat, 09 Nov 2024   Prob (F-statistic):               0.00
# Time:                        13:35:52   Log-Likelihood:            -3.4529e+06
# No. Observations:              384777   AIC:                         6.906e+06
# Df Residuals:                  384772   BIC:                         6.906e+06
# Df Model:                           4
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                3.312e+04      3.079   1.08e+04      0.000    3.31e+04    3.31e+04
# is_weekday            141.1882      3.368     41.923      0.000     134.587     147.789
# Gas_Price             -57.7370      5.290    -10.915      0.000     -68.104     -47.370
# CPI                    90.9028      5.422     16.766      0.000      80.276     101.529
# Daily_Revenue_Lag14  1.534e+04      3.486   4399.804      0.000    1.53e+04    1.53e+04
# ==============================================================================
# Omnibus:                   234181.966   Durbin-Watson:                   0.141
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3774694323.261
# Skew:                          -0.984   Prob(JB):                         0.00
# Kurtosis:                     488.220   Cond. No.                         3.22
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Ensure x_train is a DataFrame (required for VIF calculation)
x_train_df = pd.DataFrame(x_train, columns=x_train.columns)

# Calculate VIF for each feature
vif_data = pd.DataFrame()
vif_data["Feature"] = x_train_df.columns
vif_data["VIF"] = [variance_inflation_factor(x_train_df.values, i) for i in range(x_train_df.shape[1])]

# Display the VIF values
print(vif_data)
# Out:
#                Feature        VIF
# 0           is_weekday  10.173359
# 1            Gas_Price  44.560212
# 2                  CPI  33.581050
# 3  Daily_Revenue_Lag14   6.796432

# %% [markdown]
# **Build a linear regression model - 2**
#
# The is a high multi-collinearaity of Gas_Price and CPI, training another model without CPI

# %%
# Define the cutoff date
cutoff_date = '2011-11-01'

# Split the data
train_df = df_ft[df_ft['Date'] < cutoff_date]
test_df = df_ft[df_ft['Date'] >= cutoff_date]

# Separate features and target in each set if needed
x_train = train_df.drop(columns=['Daily_Revenue','BillNo','Itemname','Quantity','Date','Price','CustomerID','DateOnly','Revenue','Daily_Quantity','Country','CPI'])
y_train = train_df['Daily_Revenue']

x_test = test_df.drop(columns=['Daily_Revenue','BillNo','Itemname','Quantity','Date','Price','CustomerID','DateOnly','Revenue','Daily_Quantity','Country','CPI'])
y_test = test_df['Daily_Revenue']

# Verify the shapes
print("Training set:", x_train.shape, y_train.shape)
print("Validation set:", x_test.shape, y_test.shape)
# Out:
# Training set: (384777, 3) (384777,)
# Validation set: (107038, 3) (107038,)

# %%
# Ensure x_train is a DataFrame (required for VIF calculation)
x_train_df = pd.DataFrame(x_train, columns=x_train.columns)

# Calculate VIF for each feature
vif_data = pd.DataFrame()
vif_data["Feature"] = x_train_df.columns
vif_data["VIF"] = [variance_inflation_factor(x_train_df.values, i) for i in range(x_train_df.shape[1])]

# Display the VIF values
print(vif_data)
# Out:
#                Feature       VIF
# 0           is_weekday  9.568868
# 1            Gas_Price  9.485102
# 2  Daily_Revenue_Lag14  6.482855

# %%
# Initialize the scaler
scaler = StandardScaler()

# Fit the scaler on the training data and transform both training and test sets
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# Initialize the model
model = LinearRegression()

# Train the model on the scaled training data
model.fit(X_train_scaled, y_train)

# Make predictions on the scaled training set and evaluate
y_train_pred = model.predict(X_train_scaled)
train_mse = mean_squared_error(y_train, y_train_pred)
train_mae = mean_absolute_error(y_train, y_train_pred)
train_r2 = r2_score(y_train, y_train_pred)

print("Training Set Evaluation:")
print("Mean Squared Error:", train_mse)
print("Mean Absolute Error:", train_mae)
print("R^2 Score:", train_r2)

# Make predictions on the scaled test set and evaluate
y_test_pred = model.predict(X_test_scaled)
test_mse = mean_squared_error(y_test, y_test_pred)
test_mae = mean_absolute_error(y_test, y_test_pred)
test_r2 = r2_score(y_test, y_test_pred)

print("\nTest Set Evaluation:")
print("Mean Squared Error:", test_mse)
print("Mean Absolute Error:", test_mae)
print("R^2 Score:", test_r2)
# Out:
# Training Set Evaluation:
# Mean Squared Error: 3651475.2141091074
# Mean Absolute Error: 270.9956700108474
# R^2 Score: 0.984848598676935
#
# Test Set Evaluation:
# Mean Squared Error: 5493500.968407691
# Mean Absolute Error: 436.11952370925667
# R^2 Score: 0.9914910518227291

# %%
# Convert X_train_scaled back to a DataFrame with column names for labeling
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=x_train.columns, index=y_train.index)

# Add a constant to the model (for the intercept)
X_train_const = sm.add_constant(X_train_scaled_df)

# Fit the model using statsmodels
model = sm.OLS(y_train, X_train_const).fit()

# Print the model summary with labeled features
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Daily_Revenue   R-squared:                       0.985
# Model:                            OLS   Adj. R-squared:                  0.985
# Method:                 Least Squares   F-statistic:                 8.337e+06
# Date:                Sat, 09 Nov 2024   Prob (F-statistic):               0.00
# Time:                        13:35:53   Log-Likelihood:            -3.4531e+06
# No. Observations:              384777   AIC:                         6.906e+06
# Df Residuals:                  384773   BIC:                         6.906e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                3.312e+04      3.081   1.08e+04      0.000    3.31e+04    3.31e+04
# is_weekday            132.5295      3.329     39.808      0.000     126.004     139.055
# Gas_Price              14.2825      3.088      4.625      0.000       8.230      20.335
# Daily_Revenue_Lag14  1.536e+04      3.330   4611.153      0.000    1.53e+04    1.54e+04
# ==============================================================================
# Omnibus:                   235148.131   Durbin-Watson:                   0.142
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       3782968695.446
# Skew:                          -0.997   Prob(JB):                         0.00
# Kurtosis:                     488.751   Cond. No.                         1.49
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
